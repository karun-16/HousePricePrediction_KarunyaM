# %% [markdown]
# Week 1 Internship Project
#
# Project Title:
# House Price Prediction
#
# Student:
# M KARUNYA SARMA
#
# Organization:
# XYlofy AI
#
# Dataset:
# Housing Prices Dataset (Kaggle)
#
# Objective:
# The objective of this project is to analyze housing data and develop machine learning models capable of predicting house prices based on various property features. The project also aims to identify the factors that have the greatest influence on house prices through data analysis and visualization

# %% [markdown]
# ### Importing Required Libraries
#
# In this section, the required Python libraries are imported for data manipulation, visualization, and machine learning model development.

# %%
# Importing required libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Setting visualization style
sns.set_style("whitegrid")

# Display plots inside the notebook
# %matplotlib inline

# %%
import os

os.makedirs("charts", exist_ok=True)

# %% [markdown]
# # Task 1: Data Loading and Exploration
#
# The objective of this task is to load the housing dataset and perform an initial exploration to understand its structure and quality.

# %% [markdown]
# ### Requirement 1: Load the CSV File
#
# The housing dataset file is loaded into a Pandas DataFrame for exploration and analysis.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/karun-16/HousePricePrediction_KarunyaM/main/Housing.csv"

df = pd.read_csv(url)

print("Housing dataset loaded successfully.")
# Out:
# Housing dataset loaded successfully.

# %% [markdown]
# ### Requirement 2: Display the First 10 Rows
#
# The first 10 records of the dataset are displayed to understand the available features and verify that the dataset has been loaded correctly.

# %%
# Display the first Ten rows

df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# ### Requirement 3: Check Dataset Dimensions
#
# The dimensions of the dataset are examined to determine the number of observations and variables.

# %%
# Checking the dimensions of the dataset

df.shape
# Out:
# (545, 13)

# %% [markdown]
# The dataset contains 545 observations and 13 variables. Each row represents a house, while the columns represent different housing characteristics that may influence the selling price.

# %% [markdown]
# ### Requirement 4: Identify the Target and Feature Variables
#
# The target variable and feature variables are identified for machine learning model development.

# %%
# Displaying all column names

df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ### Variable Identification
#
# The dataset contains 13 variables. The price column is selected as the target variable, while the remaining 12 columns are treated as feature variables for prediction.

# %% [markdown]
# ### Target Variable
#
# The target variable for this project is **price**, which represents the selling price of a house.
#
# ### Feature Variables
#
# The remaining 12 columns are treated as feature variables. These features describe various characteristics of a house, such as area, number of bedrooms, bathrooms, parking facilities, furnishing status, and other amenities that may influence the selling price.

# %% [markdown]
# The dataset contains a combination of numerical and categorical features. Numerical features include area and number of bedrooms, while categorical features include furnishing status and the availability of amenities such as air conditioning and parking.

# %% [markdown]
# ### Requirement 5: Check Data Types and Missing Values
#
# The dataset is examined to understand the data types of the available variables and to identify any missing values before further analysis.

# %%
# Displaying basic information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ### Data Type Observation
#
# The dataset contains 545 records and 13 variables. Among them, 6 are numerical variables and 7 are categorical variables. All columns contain 545 non-null values, indicating that there are no immediately visible missing entries in the dataset.

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ### Missing Value Observation
#
# No missing values were found in any of the 13 variables. This indicates that the dataset is complete and does not require missing value treatment before preprocessing.

# %% [markdown]
# ### Task 1 Summary
#
# Key Findings:
#
# • The dataset contains 545 records and 13 variables.
#
# • Price is the target variable.
#
# • The remaining 12 columns are feature variables.
#
# • The dataset contains both numerical and categorical data.
#
# • No missing values were identified.
#
# • The dataset is ready for data preprocessing, feature engineering, and machine learning model development.

# %% [markdown]
# # Task 2: Data Cleaning
#
# The objective of this task is to clean the housing dataset and prepare it for machine learning by handling missing values, duplicate records, categorical variables, and feature selection.

# %% [markdown]
# ### Requirement 1: Handle Missing Values
#
# The dataset is checked for missing values to determine whether any data cleaning techniques, such as filling or removing records, are required before further analysis

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ### Missing Value Observation
#
# No missing values were found in any of the dataset columns. Therefore, no missing value treatment, such as filling or removing records, was required.

# %% [markdown]
# ### Requirement 2: Remove Duplicate Rows
#
# The dataset is examined for duplicate records to ensure that each observation is unique and does not introduce unnecessary bias into the machine learning model.

# %%
# Checking for duplicate rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Observation
#
# No duplicate records were identified in the dataset. As a result, no duplicate rows were removed, and all 545 observations were retained for further analysis.

# %% [markdown]
# ### Requirement 3: Convert Categorical Variables into Numerical Form Using One-Hot Encoding
#
# The categorical variables are identified and converted into numerical features using one-hot encoding so that they can be processed by machine learning algorithms.

# %%
# Displaying categorical columns

df.select_dtypes(include='object').columns
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# The dataset contains seven categorical variables:
# mainroad, guestroom, basement, hotwaterheating,
# airconditioning, prefarea, and furnishingstatus.
# These variables must be converted into numerical
# form before they can be used for machine learning
# model development.

# %%
categorical_columns = df.select_dtypes(include='object').columns

df = pd.get_dummies(
    df,
    columns=categorical_columns,
    drop_first=True,
    dtype=int
)

print("Categorical variables encoded successfully.")
# Out:
# Categorical variables encoded successfully.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_yes                     545 non-null    int64
#  7   guestroom_yes                    545 non-null    int64
#  8   basement_yes                     545 non-null    int64
#  9   hotwaterheating_yes              545 non-null    int64
#  10  airconditioning_yes              545 non-null    int64
#  11  prefarea_yes                     545 non-null    int64
# ...

# %%
# Checking the final dimensions after encoding

df.shape
# Out:
# (545, 14)

# %% [markdown]
# After categorical encoding, the dataset contains 545 observations and 14 numerical variables. The increase in the number of columns is expected due to one-hot encoding of categorical features.

# %% [markdown]
# ### Requirement 4: Retain Meaningful Features for Price Prediction
#
# The final feature set is reviewed to ensure that only meaningful housing characteristics relevant to price prediction are retained for machine learning model development.

# %%
# Displaying final dataset columns

df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking',
#        'mainroad_yes', 'guestroom_yes', 'basement_yes', 'hotwaterheating_yes',
#        'airconditioning_yes', 'prefarea_yes',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished'],
#       dtype='object')

# %% [markdown]
# ### Observation
#
# The dataset was successfully cleaned and prepared for machine learning. No missing values or duplicate records were found. Categorical variables were converted into numerical form using one-hot encoding, making them suitable for model training. All available features were retained because they represent meaningful housing characteristics that may collectively contribute to house price prediction.

# %% [markdown]
# ### Task 2 Summary
#
# Key Findings:
#
# No missing values were found in the dataset.
#
# No duplicate records were identified.
#
# Seven categorical variables were successfully converted into numerical form using one-hot encoding.
#
# All features are now numerical and suitable for machine learning algorithms.
#
# All meaningful housing characteristics were retained for price prediction.
#
# Overall, the cleaned dataset required minimal preprocessing and is ready for exploratory data analysis and machine learning model development.

# %% [markdown]
# # Task 3: Model Building
#
# The objective of this task is to build machine learning models capable of predicting house prices using the cleaned housing dataset. The models will be trained and evaluated to compare their predictive performance.

# %% [markdown]
# ### Requirement 1: Split the Data into Training and Test Sets
#
# The cleaned dataset is divided into training and testing subsets. The training set is used to train the machine learning models, while the testing set is reserved for evaluating model performance on unseen data.

# %%
from sklearn.model_selection import train_test_split

# %%
# Separating features and target variable

X = df.drop("price", axis=1)
y = df["price"]

# %%
# Splitting the dataset

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training and testing datasets created successfully.")
# Out:
# Training and testing datasets created successfully.

# %%
print("Training set:", X_train.shape)
print("Testing set:", X_test.shape)
# Out:
# Training set: (436, 13)
# Testing set: (109, 13)

# %% [markdown]
# ### Observation
#
# The cleaned dataset was successfully divided into training and testing sets using an 80:20 ratio. The training data contains 436 observations, while the testing data contains 109 observations for evaluating model performance.

# %% [markdown]
# ### Requirement 2: Train a Linear Regression Model
#
# A Linear Regression model is trained using the training dataset to learn the relationship between the housing features and the selling price. The trained model is then used to predict house prices.

# %%
from sklearn.linear_model import LinearRegression

# %%
# Creating the Linear Regression model

lr_model = LinearRegression()

# Training the model

lr_model.fit(X_train, y_train)

print("Linear Regression model trained successfully.")
# Out:
# Linear Regression model trained successfully.

# %%
# Predicting house prices

y_pred_lr = lr_model.predict(X_test)

print("House price predictions generated successfully.")
# Out:
# House price predictions generated successfully.

# %%
# Displaying sample predictions

print("Sample predictions:")
print(y_pred_lr[:5])
# Out:
# Sample predictions:
# [5164653.90033967 7224722.29802166 3109863.24240338 4612075.32722559
#  3294646.25725955]

# %% [markdown]
# ### Observation
#
# The Linear Regression model was successfully trained using the training dataset. The model generated house price predictions for the testing dataset, indicating that it has learned the relationship between the housing features and the target variable.

# %% [markdown]
# ### Requirement 3: Evaluate the Linear Regression Model
#
# The performance of the Linear Regression model is evaluated using standard regression metrics to measure prediction accuracy and overall model effectiveness.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Calculating evaluation metrics
import numpy as np

mae_lr = mean_absolute_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))
r2_lr = r2_score(y_test, y_pred_lr)

# %%
# Displaying evaluation metrics

print("Mean Absolute Error (MAE):", mae_lr)
print("Root Mean Squared Error (RMSE):", rmse_lr)
print("R² Score:", r2_lr)
# Out:
# Mean Absolute Error (MAE): 970043.4039201636
# Root Mean Squared Error (RMSE): 1324506.9600914386
# R² Score: 0.6529242642153184

# %% [markdown]
# ### Observation
#
# The Linear Regression model was evaluated using MAE, RMSE, and R² score. The model achieved an MAE of approximately 970,043, an RMSE of approximately 1,324,507, and an R² score of 0.653. The R² value indicates that the model explains about 65% of the variation in house prices, providing a reasonable baseline for comparison with other machine learning models.

# %% [markdown]
# ## Requirement 4: Train a Random Forest Regressor
#
# A Random Forest Regressor is trained using the training dataset to capture complex relationships between housing features and house prices. The trained model is then used to generate predictions for the testing dataset.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Creating the Random Forest model

rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# Training the model

rf_model.fit(X_train, y_train)

print("Random Forest Regressor trained successfully.")
# Out:
# Random Forest Regressor trained successfully.

# %%
# Predicting house prices

y_pred_rf = rf_model.predict(X_test)

print("House price predictions generated successfully.")
# Out:
# House price predictions generated successfully.

# %%
# Displaying sample predictions

print(y_pred_rf[:5])
# Out:
# [5377680.   7287070.   3747528.75 4502120.   3748885.  ]

# %% [markdown]
# ### Observation
#
# The Random Forest Regressor was successfully trained using the training dataset and generated predictions for the testing dataset. The model can capture complex patterns in the housing data and will be compared with the Linear Regression model to determine which provides better prediction performance.

# %% [markdown]
# ## Requirement 5: Evaluate the Random Forest Regressor
#
# The performance of the Random Forest Regressor is evaluated using MAE, RMSE, and R² score to measure prediction accuracy and compare it with the Linear Regression model.

# %%
# Calculating evaluation metrics

mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = mean_squared_error(y_test, y_pred_rf) ** 0.5
r2_rf = r2_score(y_test, y_pred_rf)

# %%
# Displaying evaluation metrics

print("Mean Absolute Error (MAE):", mae_rf)
print("Root Mean Squared Error (RMSE):", rmse_rf)
print("R² Score:", r2_rf)
# Out:
# Mean Absolute Error (MAE): 1021546.0353211008
# Root Mean Squared Error (RMSE): 1400565.9728553821
# R² Score: 0.611918531405699

# %% [markdown]
# ### Observation
#
# The Random Forest Regressor was evaluated using MAE, RMSE, and R² score. The model achieved an MAE of approximately 1,021,546, an RMSE of approximately 1,400,566, and an R² score of 0.612. These results will be compared with those of the Linear Regression model to determine the better-performing approach for this dataset.

# %% [markdown]
# ## Requirement 6: Compare Model Performance
#
# The performance of the Linear Regression and Random Forest Regressor models is compared using MAE, RMSE, and R² score to identify the better-performing model for house price prediction.

# %%
# Creating a comparison table

comparison = pd.DataFrame({
    "Metric": ["MAE", "RMSE", "R² Score"],
    "Linear Regression": [mae_lr, rmse_lr, r2_lr],
    "Random Forest": [mae_rf, rmse_rf, r2_rf]
})

comparison
# Out:
#      Metric  Linear Regression  Random Forest
# 0       MAE       9.700434e+05   1.021546e+06
# 1      RMSE       1.324507e+06   1.400566e+06
# 2  R² Score       6.529243e-01   6.119185e-01

# %% [markdown]
# ### Observation
#
# The performance comparison shows that the Linear Regression model achieved lower MAE and RMSE values and a higher R² score than the Random Forest Regressor. Based on these evaluation metrics, Linear Regression provided better prediction performance for this housing dataset and is the preferred model among the two approaches tested.

# %% [markdown]
# # Task 3 Summary
#
# ## Key Findings:
#
# - The housing dataset was successfully divided into training and testing sets using an 80:20 ratio.
# - A Linear Regression model was trained and evaluated using MAE, RMSE, and R² score.
# - A Random Forest Regressor was also trained and evaluated using the same performance metrics.
# - The performance comparison showed that the Linear Regression model achieved lower prediction errors and a higher R² score than the Random Forest model for this dataset.
# - Both machine learning models were successfully developed and tested for house price prediction.

# %% [markdown]
# # Task 4: Data Visualization
#
# The housing dataset is visualized to better understand the distribution of house prices and the relationships between different housing features.
#
# ## Requirement 1: Histogram of House Prices
#
# A histogram is created to visualize the distribution of house prices and identify common price ranges within the dataset.

# %%
import matplotlib.pyplot as plt

# Histogram of house prices
plt.figure(figsize=(8,5))
plt.hist(df["price"], bins=20)

plt.title("Distribution of House Prices")
plt.xlabel("House Price")
plt.ylabel("Frequency")

plt.savefig(
    "charts/histogram_house_prices.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Observation
#
# The histogram shows that house prices are not uniformly distributed. Most properties fall within the lower and middle price ranges, while relatively few houses have very high prices, indicating a positively skewed distribution.

# %% [markdown]
# ## Requirement 2: Correlation Heatmap
#
# A correlation heatmap is generated to examine the relationships between housing features and identify variables that are strongly associated with house prices.

# %%
import seaborn as sns

plt.figure(figsize=(10,8))

sns.heatmap(
    df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.savefig(
    "charts/correlation_heatmap.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Observation
#
# The correlation heatmap shows that area, bathrooms, stories, and air conditioning have relatively stronger positive relationships with house price. Some features have weaker correlations, indicating a smaller direct influence on selling price.

# %% [markdown]
# ## Requirement 3: Actual vs Predicted House Prices
#
# A scatter plot is created to compare the actual house prices with the values predicted by the Linear Regression model.

# %%
plt.figure(figsize=(8,5))

plt.scatter(y_test,y_pred_lr)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted House Prices")

plt.savefig(
    "charts/actual_vs_predicted.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Observation
#
# The scatter plot compares actual and predicted house prices generated by the Linear Regression model. Many points follow the overall pricing trend, indicating that the model captures the relationship between housing features and selling price reasonably well. Predictions for average-priced houses are generally more accurate, while some higher-priced properties show larger deviations, suggesting that expensive houses are slightly more difficult for the model to predict accurately.

# %% [markdown]
# ### Task 4 Summary
#
# ## Key Findings:
#
# - The house price distribution is positively skewed.
# - The correlation heatmap identified several features that are strongly related to house price.
# - The Actual vs Predicted scatter plot demonstrated the predictive capability of the Linear Regression model.
# - The visualizations provide valuable insights into both the dataset structure and model performance.

# %% [markdown]
# # Task 5: Insights & Summary

# %% [markdown]
# Key Insights
#
# The analysis shows that area, number of bathrooms, number of stories, and air conditioning have the strongest influence on house prices. The Linear Regression model explained about 65% of the variation in house prices, indicating that it provides reasonably accurate predictions for this dataset. An interesting finding was that the Linear Regression model slightly outperformed the Random Forest Regressor, suggesting that the relationships in the data are fairly linear. The house price distribution was positively skewed, with most houses belonging to the lower and middle price ranges and only a few high-priced properties. Based on these findings, real estate businesses should focus on property size and important amenities when estimating market value and planning investments. Overall, the project demonstrates that machine learning can support more informed property pricing decisions.

# %% [markdown]
# ## Insights and Summary
#
# - The analysis showed that property area and the number of bathrooms have the strongest positive relationships with house price, with correlation values of approximately 0.54 and 0.52 respectively.
# - Air conditioning and the number of stories also contribute positively to property value.
# - The Linear Regression model achieved an R² score of about 0.65, meaning it explains a significant portion of the variation in house prices and provides reasonably accurate estimates.
# - One interesting finding was that bathroom count had a stronger relationship with price than bedroom count.
# The scatter plot also suggests that the model predicts average-priced homes more accurately than very expensive properties.
# - Based on these findings, real estate businesses should focus on property size and important amenities when estimating house prices and pricing properties.

# %% [markdown]
# ------------------------------------------------------

# %% [markdown]
# #### Phase B Enhancement 1: Feature Importance in Random Forest Model
#
# Feature importance analysis is performed using the Random Forest Regressor to identify which housing characteristics contribute the most to house price prediction.
#
# Unlike correlation analysis, feature importance measures how useful each feature is for making predictions within the machine learning model.

# %%
# Extracting feature importance

feature_importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": rf_model.feature_importances_
})

feature_importance
# Out:
#                             Feature  Importance
# 0                              area    0.468430
# 1                          bedrooms    0.048413
# 2                         bathrooms    0.151483
# 3                           stories    0.057133
# 4                           parking    0.057455
# 5                      mainroad_yes    0.010250
# 6                     guestroom_yes    0.016724
# 7                      basement_yes    0.030823
# 8               hotwaterheating_yes    0.017226
# 9               airconditioning_yes    0.062672
# 10                     prefarea_yes    0.030689
# 11  furnishingstatus_semi-furnished    0.013692
# 12     furnishingstatus_unfurnished    0.035011

# %%
# Sorting feature importance

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance
# Out:
#                             Feature  Importance
# 0                              area    0.468430
# 2                         bathrooms    0.151483
# 9               airconditioning_yes    0.062672
# 4                           parking    0.057455
# 3                           stories    0.057133
# 1                          bedrooms    0.048413
# 12     furnishingstatus_unfurnished    0.035011
# 7                      basement_yes    0.030823
# 10                     prefarea_yes    0.030689
# 8               hotwaterheating_yes    0.017226
# 6                     guestroom_yes    0.016724
# 11  furnishingstatus_semi-furnished    0.013692
# 5                      mainroad_yes    0.010250

# %% [markdown]
# ## Phase B Enhancement 1: Feature Importance Visualization
#
# A feature importance chart is created using the Random Forest Regressor to identify which housing characteristics contribute the most to house price prediction.
#
# Higher importance values indicate that the model relied more heavily on those features when making predictions.

# %%
# Plotting feature importance

plt.figure(figsize=(10,6))

plt.barh(
    feature_importance["Feature"],
    feature_importance["Importance"]
)

plt.xlabel("Feature Importance")
plt.ylabel("Housing Features")
plt.title("Feature Importance in Random Forest Model")

plt.gca().invert_yaxis()

plt.savefig(
    "charts/random_forest_feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The Random Forest model identified property area as the most influential feature for predicting house prices, accounting for nearly half of the model's predictive importance. Bathrooms ranked second, followed by amenities such as air conditioning, parking availability, and the number of stories. Features like guest rooms and furnishing status contributed less to the model's decisions. The feature importance results broadly align with the earlier correlation analysis, reinforcing confidence in the key factors affecting house prices.

# %% [markdown]
# # Phase B Enhancement 2: Random Forest Performance Analysis
#
# Although Random Forest is a powerful ensemble learning algorithm, it did not outperform the simpler Linear Regression model on this dataset.

# %%
# Training performance

rf_train_pred = rf_model.predict(X_train)

rf_train_r2 = r2_score(y_train, rf_train_pred)

# Testing performance

rf_test_r2 = r2_score(y_test, y_pred_rf)

print("Training R² Score:", rf_train_r2)
print("Testing R² Score :", rf_test_r2)
# Out:
# Training R² Score: 0.9498833271635604
# Testing R² Score : 0.611918531405699

# %% [markdown]
# ### Observation
#
# The Random Forest model achieved a very high training R² score of approximately 0.95 but a noticeably lower testing R² score of approximately 0.61. This gap suggests that the model learned patterns specific to the training data and did not generalize as effectively to unseen data, indicating overfitting. In contrast, the Linear Regression model achieved a higher testing R² score of about 0.65, suggesting that the relationship between housing features and price in this dataset is largely linear. For this particular problem, the simpler Linear Regression model provided better predictive performance on unseen data.

# %%
performance = pd.DataFrame({
    "Model": ["Linear Regression", "Random Forest"],
    "R2 Score": [r2_lr, r2_rf]
})

plt.figure(figsize=(6,4))

plt.bar(
    performance["Model"],
    performance["R2 Score"]
)

plt.ylabel("R² Score")
plt.title("Model Performance Comparison")

plt.savefig(
    "charts/model_performance_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Business Insight
#
# Although Random Forest captured complex patterns within the training data, Linear Regression generalized better and produced more reliable predictions for unseen houses. For this housing dataset, a simpler model provided better predictive stability, highlighting the importance of balancing model complexity with real-world performance.

# %% [markdown]
# ## Phase B Enhancement 3: Premium Housing Market Analysis
#
# Understanding the characteristics of the most expensive properties can provide valuable business insights for real estate agencies and investors.
#
# In this section, the top five highest-priced houses are analyzed to identify common features associated with premium properties.

# %%
# Top 5 most expensive houses

top5 = df.sort_values(
    by="price",
    ascending=False
).head(5)

top5
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0  13300000  7420         4          2        3        2             1
# 2  12250000  9960         3          2        2        2             1
# 1  12250000  8960         4          4        4        3             1
# 3  12215000  7500         4          2        2        3             1
# 4  11410000  7420         4          1        2        2             1
#
#    guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# 0              0             0                    0                    1
# 2              0             1                    0                    0
# 1              0             0                    0                    1
# 3              0             1                    0                    1
# 4              1             1                    0                    1
#
#    prefarea_yes  furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# ...

# %%
# Selecting important columns

top5[
    [
        "price",
        "area",
        "bedrooms",
        "bathrooms",
        "stories",
        "parking"
    ]
]
# Out:
#       price  area  bedrooms  bathrooms  stories  parking
# 0  13300000  7420         4          2        3        2
# 2  12250000  9960         3          2        2        2
# 1  12250000  8960         4          4        4        3
# 3  12215000  7500         4          2        2        3
# 4  11410000  7420         4          1        2        2

# %%
plt.figure(figsize=(8,5))

plt.bar(
    range(len(top5)),
    top5["price"]
)

plt.xticks(
    range(len(top5)),
    ["House 1","House 2","House 3","House 4","House 5"]
)

plt.xlabel("Top Premium Houses")
plt.ylabel("Price")
plt.title("Top 5 Highest Priced Houses")

plt.savefig(
    "charts/top5_expensive_houses.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
average_top5 = top5["price"].mean()

print(
    "Average price of top 5 premium houses:",
    round(average_top5,2)
)
# Out:
# Average price of top 5 premium houses: 12285000.0

# %% [markdown]
# ### Observation
#
# The premium housing analysis shows that larger property area is a common characteristic among the highest-priced houses. Most premium properties also have multiple bedrooms, several stories, parking facilities, and additional amenities such as air conditioning. Interestingly, no single feature guarantees a high selling price, suggesting that house value is influenced by a combination of structural and location-related factors.

# %% [markdown]
# ### Business Insight
#
# For premium real estate markets, developers and agencies should focus on overall property quality rather than a single feature. Larger living area, multiple floors, parking availability, and premium amenities collectively contribute to higher property valuations and can support better pricing strategies.

# %% [markdown]
# # Phase B Enhancement 4: Custom House Price Prediction
#
# To demonstrate a practical real-world application, the trained Linear Regression model is used to estimate the selling price of a hypothetical house based on user-defined property features.
#
# This showcases how machine learning models can assist buyers, sellers, and real estate businesses in making pricing decisions.

# %%
# Sample house details for prediction

sample_house = pd.DataFrame({
    "area":[8000],
    "bedrooms":[4],
    "bathrooms":[3],
    "stories":[2],
    "parking":[2],
    "mainroad_yes":[1],
    "guestroom_yes":[1],
    "basement_yes":[1],
    "hotwaterheating_yes":[0],
    "airconditioning_yes":[1],
    "prefarea_yes":[1],
    "furnishingstatus_semi-furnished":[0],
    "furnishingstatus_unfurnished":[0]
})

# Predict house price

predicted_price = lr_model.predict(sample_house)[0]

print(f"Predicted Selling Price : ₹{predicted_price:,.2f}")

average_price = df["price"].mean()

print(f"Average Dataset Price : ₹{average_price:,.2f}")

difference=((predicted_price-average_price)/average_price)*100

print(f"Difference from Average: {difference:.2f}%")

difference=((predicted_price-average_price)/average_price)*100
# Out:
# Predicted Selling Price : ₹9,413,967.44
# Average Dataset Price : ₹4,766,729.25
# Difference from Average: 97.49%

# %%
print("="*50)
print("HOUSE PRICE PREDICTION")
print("="*50)

print(f"Predicted Selling Price : ₹{predicted_price:,.2f}")

average_price = df["price"].mean()

print(f"Average Dataset Price  : ₹{average_price:,.2f}")

difference=((predicted_price-average_price)/average_price)*100

print(f"Difference from Average: {difference:.2f}%")

print("="*50)
# Out:
# ...
# HOUSE PRICE PREDICTION
# ...
# Predicted Selling Price : ₹9,413,967.44
# Average Dataset Price  : ₹4,766,729.25
# Difference from Average: 97.49%
# ...

# %% [markdown]
# ## Observation
#
# The trained Linear Regression model estimated the sample property's value at approximately ₹91.69 lakhs. Since the house includes a large area, multiple bedrooms and bathrooms, air conditioning, and a preferred location, the predicted price is significantly above the dataset average. This demonstrates how multiple desirable features combine to increase property value.

# %% [markdown]
# ## Business Insight
#
# A predictive pricing system can help real estate agencies instantly estimate property values based on customer requirements. Buyers can compare expected prices before purchasing, while sellers can better understand how property upgrades may influence market value.

# %% [markdown]
# ### Phase B Enhancement 5: Housing Market Segmentation
#
# Understanding the distribution of premium, mid-range, and budget properties can help real estate businesses better target customers and pricing strategies.

# %%
# Creating price segments

df["Price Category"] = pd.qcut(
    df["price"],
    q=3,
    labels=["Budget", "Mid Range", "Premium"]
)

df["Price Category"].value_counts()
# Out:
# Price Category
# Budget       186
# Premium      182
# Mid Range    177
# Name: count, dtype: int64

# %%
segment_count = df["Price Category"].value_counts()

plt.figure(figsize=(7,5))

plt.bar(
    segment_count.index,
    segment_count.values
)

plt.xlabel("Market Segment")
plt.ylabel("Number of Houses")
plt.title("Housing Market Segmentation")

plt.savefig(
    "charts/housing_market_segmentation.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The housing dataset can be divided into three major market segments: Budget, Mid Range, and Premium properties. The distribution is relatively balanced, making the dataset suitable for predictive modeling across different pricing levels.

# %% [markdown]
# ### Business Insight
#
# Real estate companies can use market segmentation to design targeted marketing strategies. Budget buyers may prioritize affordability, while premium buyers may focus on luxury features such as larger areas, multiple bathrooms, and additional amenities.

# %%
df.groupby("Price Category")["area"].mean()
# Out:
# /tmp/ipykernel_10313/1056477294.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Price Category")["area"].mean()
# Price Category
# Budget       3926.838710
# Mid Range    4906.322034
# Premium      6638.648352
# Name: area, dtype: float64

# %% [markdown]
# ### Additional Finding
#
# The average property area increases consistently from the Budget segment to the Premium segment, further confirming that property size is one of the strongest drivers of house price identified throughout this project.
